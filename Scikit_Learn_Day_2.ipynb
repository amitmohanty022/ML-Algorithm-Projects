# %% [markdown]
# Linear Regression

# %%
from sklearn import datasets
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
X, y =datasets.load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
plt.scatter(X[:,0], y)

# %%
plt.scatter(X[:,1], y)

# %% [markdown]
# Train,Test,Split

# %%
x_train, x_test, y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %% [markdown]
# Creating Linear Regression Model

# %%
l_reg =linear_model.LinearRegression()
model = l_reg.fit(x_train,y_train)

# %% [markdown]
# Cheating Predictions

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([123.21091543,  78.19192216,  53.95787002, 199.47394003,
#        129.80922709, 206.66282926, 156.64109705, 103.22695262,
#         88.70869935, 190.15244149, 169.03049124, 139.0072325 ,
#         78.7900747 , 138.36282443, 103.84449426, 135.90245322,
#        120.8885942 , 221.39309051, 182.84922263, 223.8117796 ,
#        146.67890012, 207.79054729, 104.42794274, 258.13904792,
#        157.17416361,  55.21624267,  95.44710738,  88.43036047,
#        158.19730246, 121.91901446,  51.70305505, 178.85692542,
#         76.94693554, 188.10488022, 159.11929452, 124.6882657 ,
#        156.27122564, 159.35626813,  60.38443043, 173.36256472,
#        167.72290454,  63.42138278, 161.53442116, 201.80893353,
#        165.89844755, 124.77320291, 120.81272102, 235.36489577,
#         99.67372837, 233.00956334, 119.99365281,  68.10175043,
#        101.91038438, 177.38626938,  90.08838886, 196.99750533,
#        176.5277908 , 210.45140329, 181.5428676 , 254.86401532,
#        295.78341454, 163.22418897,  72.22145074, 170.93686319,
#        188.87770358,  96.41805947, 268.71634302, 199.80162418,
#        114.98149563, 252.92966666, 150.89536635, 100.74618197,
#        166.40512934, 172.77753354,  83.20410856,  98.6113675 ,
#        147.0016144 , 192.06400248, 113.27142526, 116.26705196,
#        167.20625261, 117.52767359, 250.53518054, 169.719673  ,
#         49.25541934, 162.36605988, 187.06396917, 115.36553786,
#        156.58924823])

# %%
plt.scatter(prediction,y_test)

# %% [markdown]
# Print Accuracy

# %%
print("Accuracy/R^2",l_reg.score(X,y))
# Out:
# Accuracy/R^2 0.5143612448306064

# %%
print("regression coefficient: ",l_reg.coef_)
# Out:
# regression coefficient:  [ -19.88351143 -260.49323316  515.52791899  294.40725203 -304.63345417
#   116.08577417 -204.84704731   41.13530481  566.20299675  118.61645886]

# %%
print("y_intercept",l_reg.intercept_)
# Out:
# y_intercept 152.18728158596412
