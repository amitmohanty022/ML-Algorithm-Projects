# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
car_evaluation = fetch_ucirepo(id=19)

# data (as pandas dataframes)
X = car_evaluation.data.features
y = car_evaluation.data.targets

# metadata
print(car_evaluation.metadata)

# variable information
print(car_evaluation.variables)
# Out:
# {'uci_id': 19, 'name': 'Car Evaluation', 'repository_url': 'https://archive.ics.uci.edu/dataset/19/car+evaluation', 'data_url': 'https://archive.ics.uci.edu/static/public/19/data.csv', 'abstract': 'Derived from simple hierarchical decision model, this database may be useful for testing constructive induction and structure discovery methods.', 'area': 'Other', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1728, 'num_features': 6, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1988, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5JP48', 'creators': ['Marko Bohanec'], 'intro_paper': {'ID': 249, 'type': 'NATIVE', 'title': 'Knowledge acquisition and explanation for multi-attribute decision making', 'authors': 'M. Bohanec, V. Rajkovič', 'venue': '8th Intl Workshop on Expert Systems and their Applications
# ...

# %%
car_evaluation
# Out:
# {'data': {'ids': None,
#   'features':      buying  maint  doors persons lug_boot safety
#   0     vhigh  vhigh      2       2    small    low
#   1     vhigh  vhigh      2       2    small    med
#   2     vhigh  vhigh      2       2    small   high
#   3     vhigh  vhigh      2       2      med    low
#   4     vhigh  vhigh      2       2      med    med
#   ...     ...    ...    ...     ...      ...    ...
#   1723    low    low  5more    more      med    med
#   1724    low    low  5more    more      med   high
#   1725    low    low  5more    more      big    low
#   1726    low    low  5more    more      big    med
#   1727    low    low  5more    more      big   high
#
#   [1728 rows x 6 columns],
#   'targets':       class
#   0     unacc
#   1     unacc
#   2     unacc
#   3     unacc
#   4     unacc
#   ...     ...
#   1723   good
#   1724  vgood
#   1725  unacc
#   1726   good
#   1727  vgood
#
#   [1728 rows x 1 columns],
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('car.data.csv')

# %%
df
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("https://archive.ics.uci.edu/static/public/19/data.csv")

# %%
df1
# Out:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
col_names= ['buying', 'maint', 'doors', 'persons','lug_boot','safety','class']

# %%
df1.columns = col_names

# %%
df1
# Out:
#      buying  maint  doors persons lug_boot safety  class
# 0     vhigh  vhigh      2       2    small    low  unacc
# 1     vhigh  vhigh      2       2    small    med  unacc
# 2     vhigh  vhigh      2       2    small   high  unacc
# 3     vhigh  vhigh      2       2      med    low  unacc
# 4     vhigh  vhigh      2       2      med    med  unacc
# ...     ...    ...    ...     ...      ...    ...    ...
# 1723    low    low  5more    more      med    med   good
# 1724    low    low  5more    more      med   high  vgood
# 1725    low    low  5more    more      big    low  unacc
# 1726    low    low  5more    more      big    med   good
# 1727    low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %% [markdown]
# Column names are put to the datasets

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.describe(include = 'all').T #transpose T
# Out:
#         count unique    top  freq
# vhigh    1727      4   high   432
# vhigh.1  1727      4   high   432
# 2        1727      4      3   432
# 2.1      1727      3      4   576
# small    1727      3    med   576
# low      1727      3    med   576
# unacc    1727      4  unacc  1209

# %%
for col in col_names:
  print(df1[col].value_counts())
# Out:
# buying
# vhigh    432
# high     432
# med      432
# low      432
# Name: count, dtype: int64
# maint
# vhigh    432
# high     432
# med      432
# low      432
# Name: count, dtype: int64
# doors
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: count, dtype: int64
# persons
# 2       576
# 4       576
# more    576
# Name: count, dtype: int64
# lug_boot
# small    576
# med      576
# big      576
# Name: count, dtype: int64
# safety
# low     576
# med     576
# high    576
# Name: count, dtype: int64
# class
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %% [markdown]
# Check whether duplicate value or not

# %%
df[df1.duplicated()]
# Out:
# <ipython-input-22-c206dccbdc93>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df1.duplicated()]
# Empty DataFrame
# Columns: [vhigh, vhigh.1, 2, 2.1, small, low, unacc]
# Index: []

# %% [markdown]
# Doesnot has duplicates

# %% [markdown]
# Now to convert to numeric datatype

# %% [markdown]
# Ordinal encoder

# %%
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd

# Sample DataFrame (Ensure df1 is already defined before this step)
# df1 = pd.read_csv('your_file.csv')  # Load your dataset

# Define categorical columns to be encoded
categorical_cols = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# Initialize OrdinalEncoder
oe = OrdinalEncoder()

# Fit and transform all categorical columns at once
df1[categorical_cols] = oe.fit_transform(df1[categorical_cols])

# Check the transformed DataFrame
print(df1.head())
# Out:
#    buying  maint  doors  persons  lug_boot  safety  class
# 0     3.0    3.0    0.0      0.0       2.0     1.0    2.0
# 1     3.0    3.0    0.0      0.0       2.0     2.0    2.0
# 2     3.0    3.0    0.0      0.0       2.0     0.0    2.0
# 3     3.0    3.0    0.0      0.0       1.0     1.0    2.0
# 4     3.0    3.0    0.0      0.0       1.0     2.0    2.0

# %%
df1
# Out:
#       buying  maint  doors  persons  lug_boot  safety  class
# 0        3.0    3.0    0.0      0.0       2.0     1.0    2.0
# 1        3.0    3.0    0.0      0.0       2.0     2.0    2.0
# 2        3.0    3.0    0.0      0.0       2.0     0.0    2.0
# 3        3.0    3.0    0.0      0.0       1.0     1.0    2.0
# 4        3.0    3.0    0.0      0.0       1.0     2.0    2.0
# ...      ...    ...    ...      ...       ...     ...    ...
# 1723     1.0    1.0    3.0      2.0       1.0     2.0    1.0
# 1724     1.0    1.0    3.0      2.0       1.0     0.0    3.0
# 1725     1.0    1.0    3.0      2.0       0.0     1.0    2.0
# 1726     1.0    1.0    3.0      2.0       0.0     2.0    1.0
# 1727     1.0    1.0    3.0      2.0       0.0     0.0    3.0
#
# [1728 rows x 7 columns]

# %%
X = df1.iloc[:,0:-1]
y = df.iloc[:,-1]

# %% [markdown]
# Split data into Training and testing

# %%
from sklearn.model_selection import train_test_split

# Ensure X and y are correctly defined
X = df1.drop(columns=['class'])  # Features
y = df1['class']  # Target variable

# Train-Test Split (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)  # Check split sizes
# Out:
# (1209, 6) (519, 6) (1209,) (519,)

# %%
from sklearn.ensemble import RandomForestClassifier

clf1 = RandomForestClassifier()
clf1.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# prediction

# %%
pred1 = clf1.predict(X_test)
pred1
# Out:
# array([2., 2., 2., 2., 2., 3., 2., 0., 0., 0., 2., 2., 0., 2., 2., 0., 2.,
#        2., 0., 2., 0., 0., 1., 2., 2., 2., 2., 2., 2., 2., 1., 0., 2., 0.,
#        1., 2., 2., 2., 2., 2., 2., 2., 2., 2., 3., 2., 2., 0., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 0., 0., 2., 2., 2., 0., 0., 2., 2.,
#        2., 2., 2., 0., 0., 0., 0., 0., 2., 2., 0., 2., 0., 0., 0., 2., 2.,
#        2., 2., 1., 2., 2., 2., 0., 2., 2., 2., 3., 2., 0., 0., 2., 2., 2.,
#        0., 2., 3., 0., 2., 0., 2., 2., 2., 2., 2., 1., 2., 1., 0., 2., 2.,
#        2., 2., 2., 0., 2., 2., 2., 2., 0., 1., 2., 2., 2., 0., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 0., 2., 2., 0., 2., 0., 0., 0., 0., 2.,
#        2., 2., 0., 2., 2., 2., 2., 0., 2., 2., 2., 0., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 0., 2., 2., 2., 2., 2., 0., 0., 0., 2., 0., 2., 1.,
#        2., 2., 2., 2., 2., 2., 2., 2., 0., 2., 1., 2., 2., 2., 2., 0., 2.,
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred1)
# Out:
# 0.9788053949903661

# %% [markdown]
# Validation Curve(insite of model value-plot)
# accuracy
# f1 score
# etc
# to analyse

# %%
from yellowbrick.model_selection import validation_curve

num_est = [100,200,450,500,750,1000]
print(validation_curve(RandomForestClassifier(),X = X_train, y = y_train, param_name='n_estimators', param_range=num_est, scoring ='accuracy', cv = 3))
# Out:
# ValidationCurve(ax=<Axes: title={'center': 'Validation Curve for RandomForestClassifier'}, xlabel='n_estimators', ylabel='score'>,
#                 cv=3, estimator=RandomForestClassifier(),
#                 param_name='n_estimators',
#                 param_range=array([ 100,  200,  450,  500,  750, 1000]),
#                 scoring='accuracy')

# %%
from yellowbrick.model_selection import validation_curve

depth_val = [10,7,  15,20,22]
print(validation_curve(RandomForestClassifier(),X = X_train, y = y_train, param_name='max_depth', param_range=depth_val, scoring ='accuracy', cv = 3))
# Out:
# ValidationCurve(ax=<Axes: title={'center': 'Validation Curve for RandomForestClassifier'}, xlabel='max_depth', ylabel='score'>,
#                 cv=3, estimator=RandomForestClassifier(),
#                 param_name='max_depth', param_range=array([10,  7, 15, 20, 22]),
#                 scoring='accuracy')

# %%
from yellowbrick.model_selection import validation_curve

min_samples = [3,5,4,5,8,12,15]
print(validation_curve(RandomForestClassifier(),X = X_train, y = y_train, param_name='min_samples_split', param_range=min_samples, scoring ='accuracy', cv = 3))
# Out:
# ValidationCurve(ax=<Axes: title={'center': 'Validation Curve for RandomForestClassifier'}, xlabel='min_samples_split', ylabel='score'>,
#                 cv=3, estimator=RandomForestClassifier(),
#                 param_name='min_samples_split',
#                 param_range=array([ 3,  5,  4,  5,  8, 12, 15]),
#                 scoring='accuracy')

# %%
clf2 = RandomForestClassifier(n_estimators=1000,min_samples_split = 3, max_depth=15, random_state=0)
clf2.fit(X_train, y_train)

pred2 = clf2.predict(X_test)
accuracy_score(y_test, pred2)
# Out:
# 0.976878612716763

# %% [markdown]
# Now to Extract features for our use

# %%
feature_score= pd.Series(clf2.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# %%
feature_score
# Out:
# safety      0.288486
# persons     0.240167
# buying      0.180694
# maint       0.145541
# lug_boot    0.081088
# doors       0.064025
# dtype: float64

# %%
sns.barplot(x=feature_score, y=feature_score.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
# Out:
# Text(0.5, 1.0, 'Visualizing Important Features')

# %% [markdown]
# We will remove least performing features for improving accuracy

# %%
clf3 = RandomForestClassifier()
Xn = df1.drop(['doors','lug_boot','maint'],axis = 1)
yn = df1['class']

X_train, X_test, y_train, y_test = train_test_split(Xn, yn, test_size=0.3, random_state=0)

clf3.fit(X_train, y_train)

new_pred = clf3.predict(X_test)
accuracy_score(y_test, new_pred)
# Out:
# 1.0

# %% [markdown]
# Yeyyyyyyy 100% accuracy
